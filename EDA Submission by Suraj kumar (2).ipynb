# %% [markdown]
# # **Project Name**    - **Exploratory Data Analysis** Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**  Suraj Kumar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
# Introduction Exploratory Data Analysis (EDA) is a crucial step in understanding the patterns, anomalies, and relationships within a dataset before applying any machine learning models. In this analysis, we explore a hotel booking dataset to gain insights into customer behaviors, booking patterns, and key factors affecting bookings. The dataset contains information about city and resort hotel bookings, including the booking details, customer demographics, and stay information. Data Overview The dataset comprises various features such as hotel type (city or resort), lead time, arrival date, number of nights stayed, number of adults and children, meal type, country of origin, market segment, distribution channel, repeated guest status, previous cancellations, booking status (canceled or not), and special requests. Key Findings Booking Distribution The dataset includes two types of hotels: City Hotel and Resort Hotel. City Hotels constitute about 60% of the bookings, while Resort Hotels account for the remaining 40%. The booking status reveals that approximately 37% of the bookings were canceled, indicating a relatively high cancellation rate. Seasonality and Booking Trends There is a clear seasonal pattern in bookings. Both City and Resort Hotels experience higher bookings during the summer months (June to August), with peaks during holiday periods. Lead time analysis shows that most bookings are made well in advance, with a significant number of bookings made more than three months before the stay. Customer Demographics and Preferences The majority of guests are from European countries, particularly Portugal, the UK, France, and Spain. The data shows a higher number of single adults and couples compared to families. This is reflected in the higher number of bookings for 2 adults. Guests generally prefer BB (Bed & Breakfast) meal type, followed by HB (Half Board) and FB (Full Board). Market Segmentation The dataset indicates that the majority of bookings come through Online Travel Agents (OTA) and Direct channels. Guests booking through OTA tend to have longer lead times and higher cancellation rates compared to those booking directly with the hotel. Stay Duration and Special Requests On average, guests at Resort Hotels tend to stay longer (5-7 days) compared to City Hotels (2-3 days). Special requests analysis shows that the most common requests are related to room type and bed preference. Cancellations and No-shows Analysis of cancellations reveals that the lead time is a significant factor; bookings made well in advance are more likely to be canceled. Previous cancellations by the same guest also increase the likelihood of future cancellations. Revenue Insights ADR (Average Daily Rate) analysis indicates that Resort Hotels generally have higher ADR compared to City Hotels, especially during peak seasons. Revenue management strategies can be optimized by targeting segments with lower cancellation rates and higher spending patterns. Conclusion The exploratory data analysis of the hotel booking dataset provides valuable insights into booking patterns, customer demographics, and market segmentation. Key findings highlight the importance of seasonality, lead time, and booking channels in understanding customer behavior. These insights can help hoteliers in strategic planning, optimizing revenue management, and improving customer satisfaction. Further analysis and modeling could predict booking cancellations, optimize pricing strategies, and personalize marketing efforts to enhance overall performance. make is like humanize ChatGPT Exploratory Data Analysis of Hotel Booking Data Introduction Exploratory Data Analysis (EDA) is an essential process in understanding the nuances and hidden patterns within a dataset. In this analysis, we delve into a hotel booking dataset to uncover insights about customer behaviors, booking trends, and factors influencing reservations. This dataset includes a wealth of information on city and resort hotel bookings, detailing everything from booking dates to customer demographics and stay particulars. Data Overview The dataset includes various features such as the type of hotel (city or resort), lead time, arrival date, length of stay, number of adults and children, meal plan, country of origin, market segment, distribution channel, repeat guest status, previous cancellations, booking status (canceled or not), and special requests. Key Insights Booking Distribution Our dataset reveals a significant preference for City Hotels, which account for about 60% of the bookings, while Resort Hotels make up the remaining 40%. The analysis shows that about 37% of all bookings end up being canceled, which is quite a high rate. Seasonality and Booking Trends Bookings show clear seasonality, peaking in the summer months (June to August) and during holidays. This trend is seen in both City and Resort Hotels. Lead time, or the period between booking and the stay date, varies widely. However, many bookings are made well in advance, often more than three months ahead. Customer Demographics and Preferences Most guests come from European countries, with Portugal, the UK, France, and Spain being the top contributors. The dataset indicates a higher frequency of bookings by single adults and couples compared to families. This is reflected in the predominance of bookings for two adults. Bed & Breakfast (BB) is the most popular meal plan among guests, followed by Half Board (HB) and Full Board (FB). Market Segmentation A significant number of bookings come through Online Travel Agents (OTAs) and direct bookings via the hotel’s own channels. Bookings made through OTAs often have longer lead times and higher cancellation rates compared to direct bookings. Stay Duration and Special Requests Guests tend to stay longer at Resort Hotels, typically between 5-7 days, while stays at City Hotels usually last 2-3 days. Special requests are common, with the majority related to room type and bed preferences. Cancellations and No-shows Cancellations are more likely with longer lead times; bookings made far in advance are prone to higher cancellation rates. Guests with a history of cancellations are more likely to cancel future bookings. Revenue Insights The Average Daily Rate (ADR) tends to be higher for Resort Hotels compared to City Hotels, especially during peak seasons. Effective revenue management could focus on segments with lower cancellation rates and higher spending patterns. Conclusion The exploratory analysis of the hotel booking dataset provides a rich understanding of booking behaviors, customer demographics, and market segmentation. These insights underline the importance of seasonality, lead time, and booking channels in shaping customer behaviors. For hoteliers, such information is invaluable for strategic planning, optimizing revenue management, and enhancing customer satisfaction. Moving forward, deeper analysis and predictive modeling can help in anticipating booking cancellations, fine-tuning pricing strategies, and tailoring marketing efforts to improve overall performance.
# ---

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.
#
# https://github.com/surajsamm/Hotel-Booking-Analysis-Almabetter-

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# Objective
#
# Perform an Exploratory Data Analysis (EDA) on the hotel booking dataset to identify patterns, trends, and factors influencing hotel bookings. This includes analyzing booking trends, cancellation rates, customer segmentation, and seasonal variations.
#
# Key Tasks
#
# Data Cleaning: Handle missing values and outliers, convert categorical variables, and create new features.
#
# Descriptive Analysis: Provide summary statistics and visualize key variables.
#
# Booking Trends: Analyze booking patterns over time and compare resort and city hotels.
#
# Cancellation Analysis: Examine cancellation rates and factors influencing cancellations.
#
# Customer Segmentation: Segment customers by booking behavior and demographics.
#
# Special Requests: Analyze the frequency and types of special requests.
#
# Seasonal Analysis: Study seasonal trends and their impact on bookings.
#
# Market Analysis: Evaluate market segments and distribution channels' performance.
#
# **Deliverables**
#
# EDA report with visualizations and insights.
#
# Key findings and actionable recommendations.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.
#
# Business objectives generally revolve around maximizing revenue, optimizing product levels, and increasing guest satisfaction in the hospitality industry Specific objectives may include:
#
# Increased revenues: Revenues have increased through effective pricing strategies, increased sales, and better living conditions.
#
# Improving guest satisfaction: Improving the guest experience through personalized services, efficient operations and efficient customer support.
#
# Operational efficiencies: Streamlining operations to reduce costs, reduce book cutoffs and maximize resource utilization.
#
# Market Competition: Stay competitive by using data-driven insights to adapt to market trends, customer preferences, and competitor strategies.
#
# Growth and Growth: To achieve sustainable growth by expanding market share, attracting repeat guests and maintaining brand reputation.
#
# These goals aim to drive long-term profitability, customer loyalty and overall business success in the hospitality industry. Each goal is interconnected, requiring extensive data analysis and strategic decision making to achieve the desired results.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from bs4 import BeautifulSoup
import requests

sns.set(style="whitegrid")
plt.style.use('ggplot')

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
file_path = '/content/drive/MyDrive/Copy of Hotel Bookings.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# It is a function in pandas is used to display the first few rows of a DataFrame.
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
#The first element of the tuple is the number of rows, and the second element is the number of columns.
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
#The number of non-null entries in each column.
#The data type of each column.
#The memory usage of the DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# function in pandas calculates the number of duplicate rows in a DataFrame
df.duplicated().sum()
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
#To find the number of missing values in each column of your DataFrame
missval=df.isnull().sum().sort_values(ascending=False)
print(missval)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
# Visualizing the missing values
#used to visualize data matrices, particularly for understanding patterns in missing data
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The above dataset has 119390 rows and 32 columns. There are mising values and duplicate values in the dataset.
#
# **Duplicate Values**       31994
#
# **Missing Values/Null Values Count**
#
# company     112593
#
# agent       16340
#
# country     488
#
# children    4

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
#display the column names of DataFrame
col=df.columns
col
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
#it is a function in pandas provides a summary of statistics for all columns in the DataFrame
df.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# hotel: The name of the hotel where the reservation was made.
#
# is_canceled: Indicates whether the reservation was canceled (1) or not (0).
#
# lead_time: Number of days between booking the reservation and the arrival date.
#
# arrival_date_year: Year of the guest's arrival.
#
# arrival_date_month: Month of the guest's arrival (e.g., January = 1).
#
# arrival_date_week_number: Week number of the year for the arrival date (e.g., 1st week, 2nd week).
#
# arrival_date_day_of_month: Day of the month for the guest's arrival (e.g., 1st, 2nd).
#
# stays_in_weekend_nights: Number of nights the guest stays over a weekend (Friday-Saturday).
#
# stays_in_week_nights: Number of nights the guest stays over weekdays (Sunday-Thursday).
#
# adults: Number of adult guests in the reservation.
#
# children: Number of children guests in the reservation.
#
# babies: Number of babies in the reservation.
#
# meal: Type of meal plan included (e.g., BB - Bed and Breakfast).
#
# country: Guest's home country.
#
# market_segment: Category of guest (e.g., Corporate, Leisure).
#
# distribution_channel: How the reservation was made (e.g., Online Travel Agency, Direct).
#
# is_repeated_guest: Indicates if the guest has booked before (1) or not (0).
#
# previous_cancellations: Number of previous cancellations by the guest.
#
# previous_bookings_not_canceled: Number of previous bookings not canceled by the guest.
#
# reserved_room_type: Room type originally booked by the guest.
#
# assigned_room_type: Room type the guest was actually given.
#
# booking_changes: Number of times the reservation was modified.
#
# deposit_type: Type of deposit used to secure the reservation (e.g., No Deposit).
#
# agent: Travel agent who made the reservation (might be blank for direct bookings).
#
# company: Guest's company (might be blank for individual bookings).
#
# days_in_waiting_list: Number of days the guest waited for a room (likely 0 for most).
#
# customer_type: Guest classification type (might be blank).
#
# adr: Average daily rate paid by the guest.
#
# required_car_parking_spaces: Number of parking spaces requested by the guest.
#
# total_of_special_requests: Number of special requests made by the guest.
#
# reservation_status: Current status of the reservation (likely Canceled or Check-Out).
#
# reservation_status_date: Date the reservation status was updated.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# you can use the nunique() function, which provides the number of unique values for each column.
for uni in col.tolist():
  print(f'Number of Unique values in {uni} are {df[uni].nunique()}')
  #print(f'Number of Unique values in {uni} are {df[uni].nunique()} that are={df[uni].unique()}')
  print('\n')
# Out:
# Number of Unique values in hotel are 2
#
#
# Number of Unique values in is_canceled are 2
#
#
# Number of Unique values in lead_time are 479
#
#
# Number of Unique values in arrival_date_year are 3
#
#
# Number of Unique values in arrival_date_month are 12
#
#
# Number of Unique values in arrival_date_week_number are 53
#
#
# Number of Unique values in arrival_date_day_of_month are 31
#
#
# Number of Unique values in stays_in_weekend_nights are 17
#
#
# Number of Unique values in stays_in_week_nights are 35
#
#
# Number of Unique values in adults are 14
#
#
# Number of Unique values in children are 5
#
#
# Number of Unique values in babies are 5
#
#
# Number of Unique values in meal are 5
#
#
# Number of Unique values in country are 177
#
#
# Number of Unique values in market_segment are 8
#
#
# Number of Unique values in distribution_channel are 5
#
#
# Number of Unique values in is_repeated_guest are 2
#
#
# Number of Unique values in previous_cancellations are 15
#
#
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Cheak the missing value
missval[:10]
# Out:
# company                   112593
# agent                      16340
# country                      488
# children                       4
# reserved_room_type             0
# assigned_room_type             0
# booking_changes                0
# deposit_type                   0
# hotel                          0
# previous_cancellations         0
# dtype: int64

# %%
# cheak null% value in each col
#first null% of company
company_null=df['company'].isnull().sum()/len(df)*100
company_null
# Out:
# 94.30689337465449

# %%
#null% of agent
agent_null=df['agent'].isnull().sum()/len(df)*100
agent_null
# Out:
# 13.686238378423655

# %%
#null% of country
country_null=df['country'].isnull().sum()/len(df)*100
country_null
# Out:
# 0.40874445095904177

# %%
#replace null value to 0 in country col
#is used to fill missing values
df['children']=df['children'].fillna(0)
df['children'].isnull().sum()
# Out:
# 0

# %%
#replace null value in "agent" colum by mean
#This approach is useful for numerical columns where replacing missing values with the mean helps maintain the overall statistical properties of the dataset.
df['agent']=df['agent'].fillna(df['agent'].mean())
df['agent'].isnull().sum()
# Out:
# 0

# %%
#remove missing data of 0.40% in country
#is used to remove rows from the DataFrame
#dropping rows containing NaN values specifically in the 'country' column.
df=df.dropna(subset=['country'])

# %%
#drop compant colum because its have 94% null value
#is used to drop (remove) the 'company' column
df=df.drop('company',axis=1)

# %%
#now cheak shape and null value
print(df.shape)
print(df.isnull().sum())
# Out:
# (118902, 31)
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# ...

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118902 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118902 non-null  object
#  1   is_canceled                     118902 non-null  int64
#  2   lead_time                       118902 non-null  int64
#  3   arrival_date_year               118902 non-null  int64
#  4   arrival_date_month              118902 non-null  object
#  5   arrival_date_week_number        118902 non-null  int64
#  6   arrival_date_day_of_month       118902 non-null  int64
#  7   stays_in_weekend_nights         118902 non-null  int64
#  8   stays_in_week_nights            118902 non-null  int64
#  9   adults                          118902 non-null  int64
#  10  children                        118902 non-null  float64
#  11  babies                          118902 non-null  int64
# ...

# %%
#total stay in night
df['total_stay_night']=df['stays_in_weekend_nights']+df['stays_in_week_nights']
df['total_stay_night']
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         2
#          ..
# 119385    7
# 119386    7
# 119387    7
# 119388    7
# 119389    9
# Name: total_stay_night, Length: 118902, dtype: int64

# %%
#create colum revnue using total stay *adr
df['revenue']=df['total_stay_night']*df['adr']
df['revenue']
# Out:
# 0            0.00
# 1            0.00
# 2           75.00
# 3           75.00
# 4          196.00
#            ...
# 119385     672.98
# 119386    1578.01
# 119387    1103.97
# 119388     730.80
# 119389    1360.80
# Name: revenue, Length: 118902, dtype: float64

# %%
#total guest come for each booking
df['total_guest']=df['adults']+df['children']+df['babies']
df['total_guest'].sum()
# Out:
# 234303.0

# %%
#replace the value from colum is_cancelled 0 or 1 to not cancelled or is cancelled
df['is_cancelled']=df['is_canceled'].replace({0:'Not Cancelled',1:'Cancelled'})
df['is_cancelled']
# Out:
# 0         Not Cancelled
# 1         Not Cancelled
# 2         Not Cancelled
# 3         Not Cancelled
# 4         Not Cancelled
#               ...
# 119385    Not Cancelled
# 119386    Not Cancelled
# 119387    Not Cancelled
# 119388    Not Cancelled
# 119389    Not Cancelled
# Name: is_cancelled, Length: 118902, dtype: object

# %%
# do the same with reapated guest colum
df['is_repeated_guest']=df['is_repeated_guest'].replace({0:'Not Repeated',1:'Repeated'})
df['is_repeated_guest']
# Out:
# 0         Not Repeated
# 1         Not Repeated
# 2         Not Repeated
# 3         Not Repeated
# 4         Not Repeated
#               ...
# 119385    Not Repeated
# 119386    Not Repeated
# 119387    Not Repeated
# 119388    Not Repeated
# 119389    Not Repeated
# Name: is_repeated_guest, Length: 118902, dtype: object

# %%
#cheak revnue hotal wise
df.groupby('hotel')['revenue'].sum()
# Out:
# hotel
# City Hotel      25276109.96
# Resort Hotel    17344700.02
# Name: revenue, dtype: float64

# %%
# Calculate number of bookings for each hotel type
# Calculate percentages
city_hotel_bookings = df[df['hotel'] == 'City Hotel'].shape[0]
resort_hotel_bookings = df[df['hotel'] == 'Resort Hotel'].shape[0]

total_bookings = city_hotel_bookings + resort_hotel_bookings

city_hotel_percentage = (city_hotel_bookings / total_bookings) * 100
resort_hotel_percentage = (resort_hotel_bookings / total_bookings) * 100

print(f"Percentage of City Hotel bookings: {city_hotel_percentage:.2f}%")
print(f"Percentage of Resort Hotel bookings: {resort_hotel_percentage:.2f}%")
# Out:
# Percentage of City Hotel bookings: 66.70%
# Percentage of Resort Hotel bookings: 33.30%

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
#
#
# **Check for missing values:**
#
# It identified characters with invalid values ​​and checked the missing percentage.
#
# **Specific network monitoring:**
#
# The pillars of the company fell due to the loss of high values ​​(94%).
# The missing agent column imputed values ​​are the mean.
# The state color replaces missing values ​​with 0 (assume a class or flag-like variable where 0 can represent ‘unknown’ or ‘not shown’).
#
# first null% of company=94.30689337465449
# null% of agent=13.686238378423655
# null% of country=0.40874445095904177
#
#
# **Data Hygiene:**
#
# Missing rows in the ‘Country’ column were removed, accounting for 0.40% of the data set.
# Data Transformation and Feature Engineering:
#
# A new column called 'revenue' was created using the formula total_stay * adr.
# The binary columns were converted into categorical variables 'is_canceled' and 'is_repeated_guest' ('uncanceled' vs 'canceled', 'repeat guest' vs 'first time guest').
#
# **Analysis of all migrations:**
#
# The distribution and insights of providing family accommodation for the night in exchange for registration were examined.
#
# **Revenue Analysis by Hotel Type:**
#
# The revenues of hotels (City Hotel vs Resort Hotel) were analyzed and compared.
#
# **Insights and Trends:**
#
# Patterns observed in book circulation, visitor numbers, and revenue.
# The relationship between variables such as lead time, booking changes and revenue was examined.
#
# cheak revnue hotal wise
# hotel
# City Hotel      25279469.96
# Resort Hotel    17444027.57
#
# These functions and insights help understand data quality, prepare data for analysis, and uncover trends that can inform business decisions in the hospitality industry Each step of the process contributes to clean data and insights which makes more sense for strategic planning and optimizing performance.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#plot histogram
df.hist(figsize=(30,15))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A histogram is chosen because it effectively displays the frequency distribution of a dataset, making it easy to identify patterns and interpret the data visually.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# Insights from a histogram can include:
#
# The distribution shape
#
# Data concentration and spread
#
# Identification of outliers
#
# Frequency of different ranges within the dataset

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# **Positive business impact:**
#
# Insights gained from histograms of hotel bookings, such as peak booking times, popular room types, and customer demographics, can contribute to better pricing, more efficient allocation , and make appropriate marketing efforts to increase hotel bookings in a timely manner
#
# **Negative Growth Insights:**
#
#  If the histogram reveals a sharp decline in orders or a seasonal high cancellation rate, it could indicate issues with service quality, pricing, or market competition ho Addressing these issues may reveal uneven progress initially but ultimately improve business strategies and customer satisfaction It helps, and that leads to better results.

# %% [markdown]
# #### Chart - 2

# %%
#plot piechart from how many % or city hotel and resort hotel book plot piee chart
# Pie chart for booking distribution by hotel type
labels = ['City Hotel', 'Resort Hotel']
sizes = [city_hotel_percentage, resort_hotel_percentage] # Add sizes array
colors = ['#ff9999', '#66b3ff']
explode = (0.1, 0)  # explode 1st slice
fig1, ax1 = plt.subplots()
wedges, texts, autotexts = ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90, wedgeprops={'edgecolor': 'black'}) # Remove extra indent
ax1.axis('equal')
plt.title('Booking Distribution by Hotel Type')

plt.legend(wedges, labels,
          title="Hotel Type",
          loc="upper left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A pie chart was chosen because it effectively shows the percentage distribution of bookings between City Hotels and Resort Hotels, making it easy to visualize how each category contributes to the total bookings in a clear and straightforward manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The pie chart provides a quick overview:
#
# It shows the proportion of bookings between City Hotels and Resort Hotels.
#
# Highlights relative popularity and market share of each hotel type.
#
# Offers insights into customer preferences and seasonal variations in booking patterns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# **Positive Impact:**
#
# Insights can optimize marketing strategies, enhance operational decisions, and improve revenue management based on customer preferences and booking patterns.
#
# **Negative Impact:**
#
# Misinterpreting or neglecting insights could lead to missed opportunities, inefficient resource allocation, and potential dissatisfaction among customers if services do not align with preferences or seasonal demands.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#create a chart for canceled and not canceled hotel
cancelled_counts = df['is_canceled'].value_counts()
plt.pie(cancelled_counts, labels=['Not Canceled', 'Canceled'], autopct='%1.1f%%', colors=['green', 'red'], startangle=140)
plt.title('Canceled vs Not Canceled Hotel Bookings')
plt.axis('equal')
plt.legend(loc="upper left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose a pie chart because it visually represents the percentage distribution between canceled and not canceled hotel bookings clearly and simply, making it easy to understand the relative frequency of each category at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# In short, the chart provides insights into cancellation rates, booking behavior patterns, operational impacts, customer preferences, and opportunities for optimizing revenue management strategies based on observed cancellation trends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# **Positive Impact:**
#
#  Insights into cancellation rates and booking behavior can lead to more effective revenue management, operational efficiencies, and improved customer satisfaction, thereby creating positive business impacts.
#
# **Negative Impact:**
#
#  Misinterpreting or neglecting cancellation trends could lead to missed revenue opportunities, inefficient resource allocation, and potential dissatisfaction among guests if not aligned with their expectations or needs.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#create chart of total stay
df['total_stays'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
plt.figure(figsize=(20, 6))
sns.violinplot(x='arrival_date_week_number', y='total_stays', data=df, hue='hotel')
plt.title('Total Stays by Week Number')
plt.xlabel('Week Number')
plt.ylabel('Total Stays')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# In short, the violin plot was chosen because it effectively displays the distribution and density of stays across different week numbers, allowing for easy comparison of patterns and variations in booking behavior over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The violin plot provides insights into:
#
# Variability and patterns in stay durations across different weeks.
#
# Typical stay durations and outliers.
#
# Comparisons between weeks for understanding trends in booking behavior.
# These insights aid in strategic decision-making for optimizing operations and enhancing guest satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# **Positive Impact:**
#
# Insights on variability, typical stay durations, and booking trends can optimize pricing strategies, improve resource allocation, and enhance guest satisfaction, leading to increased revenue and operational efficiency.
#
# **Negative Impact:**
#
# Misinterpreting trends or failing to address outliers effectively could lead to missed revenue opportunities, inefficient operations, and potential dissatisfaction among guests, resulting in negative growth or decreased profitability.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#create a chart for distribution of booking by agent
plt.figure(figsize=(20, 6))
sns.countplot(x='agent', data=df)
plt.title('Distribution of Bookings by Agent')
plt.xlabel('Agent')
plt.ylabel('Number of Bookings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The count plot (sns.countplot) was selected because it efficiently displays the distribution of bookings across different agents by visually representing the frequency of each agent's bookings in a clear and straightforward manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Agent performance by showing booking distribution.
#
# Workload balance among agents.
#
# Resource management needs based on booking volumes.
#
# Operational efficiency in handling bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# **Positive Impact:**
#
# Insights can optimize resource allocation, improve agent performance, enhance customer service, and guide training initiatives.
#
# **Negative Impact Potential:**
#
# Risks include overburdened agents, underperformance issues, operational bottlenecks, and misallocation of resources, which could impact efficiency and customer satisfaction negatively.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
#plot pie chart for month wise booking distrubtion
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['arrival_date_month'] = pd.Categorical(df['arrival_date_month'], categories=month_order, ordered=True)
monthly_bookings = df.groupby('arrival_date_month').size()

plt.figure(figsize=(10, 10))
plt.pie(monthly_bookings, labels=monthly_bookings.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Set3.colors)
plt.title('Month-wise Booking Distribution')
plt.axis('equal')
plt.tight_layout()
plt.legend(monthly_bookings.index, title='Months', loc='lower left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The pie chart was chosen to visualize the month-wise booking distribution because it effectively shows the proportion of bookings attributed to each month in a clear and concise manner. This type of chart is ideal when you want to compare the relative contribution of each category (in this case, each month) to the whole (total bookings), making it easy to grasp the distribution pattern at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# From the pie chart showing the month-wise booking distribution, the insights could include:
#
# Peak Booking Months: Identifying which months have the highest percentage of bookings, indicating peak periods of demand.
#
# Seasonal Trends: Observing any seasonal patterns in booking behavior, such as higher bookings during summer months or lower bookings during winter.
#
# Booking Distribution: Understanding how bookings are spread across different months, which can inform marketing and operational strategies to optimize resources based on demand fluctuations throughout the year.
#
# Comparison and Analysis: Comparing the distribution of bookings across months can provide insights into changes in customer behavior or preferences over time, aiding in forecasting and planning.
#
# These insights help in better understanding booking trends and patterns, enabling businesses to adjust strategies accordingly to maximize revenue and customer satisfaction throughout the year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# **Positive Impact:**
#
# Insights can optimize resource allocation, inform strategic pricing, and enhance targeted marketing efforts, leading to improved revenue and customer satisfaction.
#
# **Negative Growth Potential:**
#
# Seasonal dependence and competition can create challenges like pricing pressures and operational strain, requiring careful management to maintain stability and growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
#chart of market segment and booking
segment_bookings = df.groupby('market_segment').size().sort_values(ascending=False).reset_index(name='count')

plt.figure(figsize=(10, 6))
sns.barplot(x='market_segment', y='count', data=segment_bookings, palette='Set2', hue='market_segment', legend=False)
plt.title('Booking Distribution by Market Segment')
plt.xlabel('Market Segment',color='green')
plt.ylabel('Number of Bookings',color='Red')
plt.xticks()
#count value
for index, row in segment_bookings.iterrows():
    plt.text(index, row['count'] + 0.2, row['count'], ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The bar chart was chosen because it effectively displays the distribution of bookings across different market segments in a clear and easy-to-compare format, making it ideal for categorical data visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The bar chart provides insights into which market segments generate the highest number of bookings, helping businesses identify key sources of revenue and potential areas for strategic focus and improvement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Yes, understanding booking distribution by market segment can positively impact business by enabling targeted marketing, improving operational efficiency, and optimizing revenue. However, over-reliance on a single segment or missing opportunities in emerging segments could lead to negative growth potential.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
#chart of total revenue and hotel type
total_revenue = df.groupby('hotel')['revenue'].sum().reset_index()

# Plotting
plt.figure(figsize=(8, 6))
plt.bar(total_revenue['hotel'], total_revenue['revenue'], color=['orange', 'green'])
plt.xlabel('Hotel')
plt.ylabel('Total Revenue')
plt.title('Total Revenue by Hotel Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The bar chart was chosen for its ability to clearly compare total revenue across different hotel types, providing straightforward insights into revenue generation by each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The chart provides insights into which hotel types generate higher revenue, guiding strategic decisions and highlighting performance differences among categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Yes, insights into revenue by hotel type can positively impact business by guiding strategic decisions on resource allocation and marketing. However, over-reliance on high-revenue segments or neglecting potential growth in other segments could pose risks to sustained business growth.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
#chart of to find average adr by hotel
#Calculates the mean (average) of the 'adr' (average daily rate) column for hotel.
avg_adr = df.groupby('hotel')['adr'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(x='hotel', y='adr', data=avg_adr,hue='hotel', palette='Set2')
plt.xlabel('Hotel')
plt.ylabel('Average ADR')
plt.title('Average ADR by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The bar chart with Seaborn ('sns.barplot') was selected because it efficiently compares average daily rates (ADR) across different hotel types, while also allowing differentiation by market segments using hue. This visualization method is clear, visually appealing, and suitable for categorical data analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The chart provides insights into comparative average daily rates (ADR) across different hotel types and market segments, aiding strategic decisions in pricing, marketing, and operational focus to optimize revenue and competitive positioning.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Yes:
#
# Insights into ADR across different hotel types and market segments can optimize pricing, marketing, and operations.
# However, over-reliance on high-ADR segments risks vulnerability to market changes, while neglecting low-ADR segments may limit overall revenue potential.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#count of Lead(Pre-Booking) Time Analysis:
plt.figure(figsize=(10, 6))
sns.histplot(df['lead_time'], bins=10, kde=True, color='skyblue')
plt.xlabel('Lead Time (days)')
plt.ylabel('Frequency')
plt.title('Lead Time Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the histogram because it effectively shows the frequency distribution of lead times in discrete intervals, making it straightforward to understand booking patterns based on the duration between booking and arrival dates.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The histogram of lead times provides insights into peak booking periods, distribution patterns, and guest booking behaviors, guiding hotels in optimizing operations and enhancing customer satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
#
# **Positive Impact:**
#
#  Understanding lead times helps hotels optimize operations, improve customer satisfaction, and enhance revenue through efficient resource allocation and strategic pricing.
#
# **Negative Impact:**
#
# Misaligned booking patterns may lead to operational challenges like staffing issues and revenue loss due to overbooking or underutilization of resources. Addressing these insights proactively is crucial to minimizing negative impacts and maximizing positive outcomes in hotel management.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
#chart of Room Type Comparison: Reserved vs Assigned
df_melted = pd.melt(df, value_vars=['reserved_room_type', 'assigned_room_type'], var_name='Room Type', value_name='Type')
plt.figure(figsize=(10, 6))
sns.countplot(x='Type', hue='Room Type', data=df_melted, palette='Set2')
plt.xlabel('Room Type')
plt.ylabel('Number of Bookings')
plt.title('Room Type Comparison: Reserved vs Assigned')
plt.legend(title='Booking Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the Count Plot because it succinctly stacks the counts of reserved and assigned room types, offering a clear comparison of categorical data in a visually straightforward manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The chart shows the frequency comparison between reserved and assigned room types, highlighting discrepancies and patterns in room allocations. This insight aids in understanding operational efficiency and customer satisfaction within the hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# **Positive Impact:**
#
# Insights from comparing reserved and assigned room types can improve operational efficiency by optimizing room allocation processes. This leads to higher customer satisfaction as guests receive their preferred room types, enhancing loyalty and positive reviews.
#
# **Negative Impact:**
#
# Persistent discrepancies between reserved and assigned room types may result in customer dissatisfaction and negative reviews. This can lead to reduced repeat bookings and increased operational costs due to inefficiencies in managing guest expectations and operational processes.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
#Chart of Booking Changes Analysis:
#0: Bookings with no changes.
#1: Bookings with one change.
#2: Bookings with two changes.
#3: Bookings with three changes.
#Changes Like :Modifying Dates,Room Type Changes,Cancellation and Rebooking.
plt.figure(figsize=(10, 6))
sns.countplot(x='booking_changes', data=df, palette='viridis')
plt.xlabel('Number of Booking Changes')
plt.ylabel('Count')
plt.title('Distribution of Bookings by Booking Changes')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-41-88d18f3d7595>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='booking_changes', data=df, palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the countplot because it efficiently displays the frequency of different levels of booking changes, providing a clear and comparative view of how often reservations are modified after initial booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The countplot of booking changes provides insights into how frequently guests modify their reservations, helping hotels anticipate operational needs, understand customer behavior, and optimize revenue management strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# **Positive Impact:**
#
# Insights from booking change analysis help hotels improve operational efficiency, enhance customer satisfaction, and optimize revenue through better resource allocation and dynamic pricing strategies.
#
# **Negative Impact:**
#
# High frequencies of booking changes may strain operations and lead to potential revenue loss due to last-minute cancellations or modifications. Implementing flexible policies and proactive strategies is essential to mitigate these challenges and maximize positive business outcomes.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
#Chart of Reservation Status Analysis:
reservation_counts = df['reservation_status'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(reservation_counts.index, reservation_counts, color=plt.cm.Set3.colors)
plt.xlabel('Reservation Status',color='red')
plt.ylabel('Count',color='red')
plt.title('Distribution of Bookings by Reservation Status')
plt.xticks()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the stacked bar chart because it effectively displays the absolute counts of each reservation status category, enabling straightforward comparisons and detailed insights into the distribution of booking statuses.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Without the specific chart and data, I can't provide precise insights. However, typically insights from a chart showing booking distribution by reservation status might include understanding the proportion of cancellations, the volume of confirmed bookings, and the frequency of completed stays. These insights help in assessing operational efficiency, revenue forecasting, and customer service strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Analyzing booking distribution by reservation status can lead to positive impacts like optimized resource allocation and enhanced revenue management. However, a high proportion of cancellations may lead to revenue loss and operational disruptions, necessitating effective management strategies.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Select specific columns for correlation heatmap
columns = df[['lead_time', 'previous_cancellations', 'previous_bookings_not_canceled',
           'booking_changes', 'total_guest', 'adr', 'days_in_waiting_list',
           'required_car_parking_spaces', 'total_of_special_requests']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(columns, annot=True, cmap='coolwarm', fmt='.2f', square=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
#
# The correlation heatmap was chosen for its ability to visually represent relationships between multiple variables through color-coded correlation coefficients, providing a clear and comprehensive overview of how variables interact with each other in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The correlation heatmap provides insights into how variables relate to each other: identifying strong positive or negative correlations, highlighting potential multicollinearity, and showing which variables may influence others. These insights help in understanding data patterns and making informed decisions based on data relationships.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
columns = ['lead_time', 'previous_cancellations', 'booking_changes', 'total_guest', 'adr', 'total_of_special_requests']
df_subset = df[columns]

# Create pair plot
sns.pairplot(df_subset)
plt.suptitle('Pair Plot Visualization', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The pair plot was chosen because it efficiently visualizes relationships between multiple variables, providing insights into correlations, distributions, and potential patterns in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Pair plots provide insights into correlations, distributions, outliers, patterns, and variable importance, aiding in understanding data relationships and guiding further analysis.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.
#
# **To better achieve business objectives:**
#
# Use data analytics to understand booking trends and customer behavior.
#
# Segment customers based on their preferences and behaviors for targeted strategies.
#
# To use predictive models to predict and improve performance.
#
# Insightfully optimize pricing, inventory management, and customer service.
#
# Monitor key metrics closely and optimize strategies in real time.
#
# Streamline operations to increase efficiency and service delivery.
#
# Continue to adjust strategies to keep pace with market trends.
#
# Focus on increasing customer satisfaction through personalized experiences.
#
# Invest in technology to support data-driven decision making.
#
# Foster a culture of innovation and change to stay competitive.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# In conclusion, data-driven insights and strategic actions are essential to successfully achieving business objectives. By understanding booking trends, segmenting customers, and using predictive models, businesses can optimize operations, improve customer satisfaction and drive growth with constant monitoring of key metrics and agile adaptation of strategies will ensure that it is always in line with market trends. Emphasis on efficiency, personalized service and innovation will further enhance the competitiveness of the hospitality industry and ensure long-term success and profitability.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
